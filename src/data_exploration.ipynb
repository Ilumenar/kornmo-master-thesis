# %%
import pandas as pd
import os

# %%
def read_csv(path):
    df = pd.read_csv(path)
    return df

# %%
data_location = "C:/Users/Sigurd/Documents/Kornmo/From the students/data"

dataset_df = read_csv(os.path.join(data_location, '../dataset_raw.csv'))

dataset_df.head()
# Out:
#    mean_temp0  mean_temp1  mean_temp2  mean_temp3  mean_temp4  mean_temp5  \
# 0         7.9        10.1         8.8         7.8         6.7         6.8
# 1         7.9        10.1         8.8         7.8         6.7         6.8
# 2         7.9        10.1         8.8         7.8         6.7         6.8
# 3         7.9        10.1         8.8         7.8         6.7         6.8
# 4        -0.6        -0.5         1.2         3.8         1.9         3.7
#
#    mean_temp6  mean_temp7  mean_temp8  mean_temp9  ...  mean_temp173  \
# 0         6.4         8.5        11.1         7.1  ...          13.6
# 1         6.4         8.5        11.1         7.1  ...          13.6
# 2         6.4         8.5        11.1         7.1  ...          13.6
# 3         6.4         8.5        11.1         7.1  ...          13.6
# 4         3.9         4.3         3.8         6.0  ...           4.4
#
#    mean_temp174  mean_temp175  mean_temp176  mean_temp177  mean_temp178  \
# ...

# %%
dataset_df = dataset_df.filter(regex=("mean_temp.*"))
dataset_df.head()
# Out:
#    mean_temp0  mean_temp1  mean_temp2  mean_temp3  mean_temp4  mean_temp5  \
# 0         7.9        10.1         8.8         7.8         6.7         6.8
# 1         7.9        10.1         8.8         7.8         6.7         6.8
# 2         7.9        10.1         8.8         7.8         6.7         6.8
# 3         7.9        10.1         8.8         7.8         6.7         6.8
# 4        -0.6        -0.5         1.2         3.8         1.9         3.7
#
#    mean_temp6  mean_temp7  mean_temp8  mean_temp9  ...  mean_temp173  \
# 0         6.4         8.5        11.1         7.1  ...          13.6
# 1         6.4         8.5        11.1         7.1  ...          13.6
# 2         6.4         8.5        11.1         7.1  ...          13.6
# 3         6.4         8.5        11.1         7.1  ...          13.6
# 4         3.9         4.3         3.8         6.0  ...           4.4
#
#    mean_temp174  mean_temp175  mean_temp176  mean_temp177  mean_temp178  \
# ...

# %%
from gdb_to_csv import read_soil
gdf = read_soil()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14480/1102285635.py in <module>
# ----> 1 import fiona
#
# ModuleNotFoundError: No module named 'fiona'
